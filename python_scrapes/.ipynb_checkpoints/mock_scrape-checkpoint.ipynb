# %%
import pandas as pd
import requests
import itertools


results = pd.DataFrame()
url_list = ["6584965", '6541965', '6584960', '6584958', '6584803' , '6584801', '6584798', '6584796', '6584793', '6584642', '6584634', 
           '6584630', '6584627', '6584497', '6584495', '6584492', '6584490', '6584487', '6584487', '6584485', '6584483', '6584480', 
           '6584370', '6584368', '6584366', '6584361', '6584358', '6584351', '6584238']
url = '6541965'

header = {
  "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.75 Safari/537.36",
  "X-Requested-With": "XMLHttpRequest"
}

for p in url_list:
    url = ('https://fantasyfootballcalculator.com/draft/' + p)
    r = requests.get(url, headers=header)
    df = pd.read_html(r.text, header = 1)
    df = df[0]
    df = df.iloc[:-1,1:13]

    for i in range(0,len(list(df))):

         df.iloc[:,i] = df.iloc[:, i].str.replace(r'(.*[A-Z]{0,1})([A-Z][a-z])', r'\1  \2')
         df.iloc[:,i] = df.iloc[:, i].str.replace(r'(.*) ([A-Z]{2})(.*)', r'\1')

    full_list = []
    results_list = []

    for i in range(0,len((df))):
        results_list.append(df.iloc[i,:])

    full_list.append ( list(itertools.chain.from_iterable(results_list)))
    try:
  

        results[p] = list(itertools.chain.from_iterable(results_list))
    except Exception:
        pass

results.to_csv('mock_results.csv')

# %%
results
# Out:
#                     6584965                 6541965                6584960  \
# 0          Saquon  Barkley    ChristianMc  Caffrey   ChristianMc  Caffrey
# 1     ChristianMc  Caffrey           Alvin  Kamara        Saquon  Barkley
# 2            Alvin  Kamara         Saquon  Barkley          Alvin  Kamara
# 3         Ezekiel  Elliott        Ezekiel  Elliott         David  Johnson
# 4           David  Johnson            LeVeon  Bell       Ezekiel  Elliott
# 5         DeAndre  Hopkins           James  Conner       DeAndre  Hopkins
# 6           Davante  Adams          David  Johnson           LeVeon  Bell
# 7              Nick  Chubb          Davante  Adams            Nick  Chubb
# 8             LeVeon  Bell        DeAndre  Hopkins         Davante  Adams
# 9             Todd  Gurley            Julio  Jones          James  Conner
# 10           James  Conner             Nick  Chubb      OdellBeckham   Jr
# 11              Joe  Mixon              Joe  Mixon        Michael  Thomas
# ...

# %%
df = pd.DataFrame()

# %%
df['s'] = [1,2,3,4]

# %%
df['q'] = [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-84-93b188dc9c61> in <module>
# ----> 1 df['q'] = [1,2,3]
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3117         else:
#    3118             # set column
# -> 3119             self._set_item(key, value)
#    3120
#    3121     def _setitem_slice(self, key, value):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3192
#    3193         self._ensure_valid_index(value)
# -> 3194         value = self._sanitize_column(key, value)
#    3195         NDFrame._set_item(self, key, value)
#    3196
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3389
#    3390             # turn me into an ndarray
# -> 3391             value = _sanitize_index(value, self.index, copy=False)
# ...
